# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
metadata_country = pd.read_csv('/content/Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_900.csv')
metadata_indicator = pd.read_csv('/content/Metadata_Indicator_API_SP.POP.TOTL_DS2_en_csv_v2_900.csv')

# %%
data = pd.read_csv('/content/API_SP.POP.TOTL_DS2_en_csv_v2_900.csv', delimiter=';')

# %%
metadata_country.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
metadata_indicator.head()
# Out:
#   INDICATOR_CODE     INDICATOR_NAME  \
# 0    SP.POP.TOTL  Population, total
#
#                                          SOURCE_NOTE  \
# 0  Total population is based on the de facto defi...
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4
# 0  (1) United Nations Population Division. World ...         NaN

# %%
# Load the data, skipping the first two rows containing metadata
data = pd.read_csv('/content/API_SP.POP.TOTL_DS2_en_csv_v2_900.csv', skiprows=2)

# Clean up column names (strip spaces, remove extra quotes if present)
data.columns = data.columns.str.strip().str.replace('"', '')

# Display the first few rows of the cleaned DataFrame
print(data.head())

# Check the structure of the DataFrame
print(data.info())
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Last Updated Date  \
# ...

# %%
data.describe()
# Out:
#        Last Updated Date    2024-12-16  Unnamed: 2
# count       2.660000e+02  2.660000e+02         0.0
# mean        3.243006e+08  3.275534e+08         NaN
# std         1.008072e+09  1.016866e+09         NaN
# min         2.022000e+03  2.023000e+03         NaN
# 25%         1.776958e+06  1.774228e+06         NaN
# 50%         1.047541e+07  1.061151e+07         NaN
# 75%         6.412847e+07  6.576630e+07         NaN
# max         7.989982e+09  8.061876e+09         NaN

# %%
data.isnull().sum()
# Out:
# Last Updated Date      1
# 2024-12-16             1
# Unnamed: 2           267
# dtype: int64

# %%
# Gender distribution
categories = ['Male', 'Female', 'Other']
counts = [120, 150, 30]

plt.bar(categories, counts, color=['blue', 'pink', 'purple'])
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution')
plt.show()

# %%
#  Age distribution
ages = np.random.normal(30, 10, 500)  # Generate random ages with mean=30 and std=10

plt.hist(ages, bins=10, color='green', edgecolor='black', alpha=0.7)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()
